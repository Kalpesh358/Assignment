# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalpesh358/Assignment/blob/main/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import zipfile

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/drive/MyDrive/kaggle.json" ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# !pip install -q kaggle

# %%
# Download a dataset
# !kaggle datasets download -d zahidmughal2343/employee-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/zahidmughal2343/employee-data
# License(s): other

# %%
df = pd.read_csv('/content/drive/MyDrive/Employee 1000x.csv')

# %%
df.head()  # Displays first 5 rows by default
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female           tsharp@example.net
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
# 4      5      Bobby   Pittman  Female    blevinsmorgan@example.com
#
#                    Phone Date of birth                          Job Title
# 0     (971)643-6089x9160      17-08-21              Editor, commissioning
# 1  +1-114-355-1841x78347      28-06-69                 Broadcast engineer
# 2             9017807728      25-09-15                   Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78              Multimedia specialist
# 4             3739847538      17-11-89  Planning and development surveyor

# %%
df.head(25)
# Out:
#     Index First Name   Last Name     Sex                         Email  \
# 0       1       Sara     Mcguire  Female            tsharp@example.net
# 1       2     Alisha      Hebert    Male    vincentgarrett@example.net
# 2       3  Gwendolyn    Sheppard    Male   mercadojonathan@example.com
# 3       4   Kristine      Mccann  Female         lindsay55@example.com
# 4       5      Bobby     Pittman  Female     blevinsmorgan@example.com
# 5       6     Calvin      Ramsey  Female         loretta85@example.com
# 6       7     Collin     Allison    Male           yvaughn@example.net
# 7       8   Nicholas      Branch    Male        greerjimmy@example.net
# 8       9       Emma    Robinson  Female    charleshiggins@example.org
# 9      10      Pedro     Cordova    Male          leslie08@example.com
# 10     11       Jean     Aguilar    Male         raymond24@example.org
# 11     12     Dwayne  Hutchinson  Female         preston28@example.net
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          10000 non-null  int64
#  1   First Name     10000 non-null  object
#  2   Last Name      10000 non-null  object
#  3   Sex            10000 non-null  object
#  4   Email          10000 non-null  object
#  5   Phone          10000 non-null  object
#  6   Date of birth  10000 non-null  object
#  7   Job Title      10000 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 625.1+ KB

# %%
df.describe()
# Out:
#              Index
# count  10000.00000
# mean    5000.50000
# std     2886.89568
# min        1.00000
# 25%     2500.75000
# 50%     5000.50000
# 75%     7500.25000
# max    10000.00000

# %%
df.isnull().sum()
# Out:
# Index            0
# First Name       0
# Last Name        0
# Sex              0
# Email            0
# Phone            0
# Date of birth    0
# Job Title        0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.dtypes
# Out:
# Index             int64
# First Name       object
# Last Name        object
# Sex              object
# Email            object
# Phone            object
# Date of birth    object
# Job Title        object
# dtype: object

# %%
import matplotlib.pyplot as plt
df.hist(bins=20, figsize=(10, 8))
plt.show()

# %%
Age_stats = df['Email'].describe()
print(Age_stats)
# Out:
# count                   10000
# unique                   9936
# top       bnorton@example.net
# freq                        3
# Name: Email, dtype: object

# %%
variable = 'Email'

# Plot the boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x=df[variable])
plt.title(f'Boxplot for {variable}')
plt.xlabel(variable)
plt.show()
